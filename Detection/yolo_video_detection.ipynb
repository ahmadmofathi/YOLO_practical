# %%
from ultralytics import YOLO
import cv2

# %%
model = YOLO('yolov8n.pt')
results = model(source="F:\\University\\Last year of Hell - First Term\\Computer Vision\\Practical\\Practical Task\\Detection\\854204-hd_1920_1080_30fps.mp4", stream=True, show=True, conf=0.4, save=True)

for result in results:
    frame = result.plot()  
    cv2.imshow("Processed Frame", frame)
# Out:
# video 1/1 (frame 1/450) F:\University\Last year of Hell - First Term\Computer Vision\Practical\Practical Task\Detection\854204-hd_1920_1080_30fps.mp4: 384x640 4 persons, 1 car, 1 bench, 110.8ms
# video 1/1 (frame 2/450) F:\University\Last year of Hell - First Term\Computer Vision\Practical\Practical Task\Detection\854204-hd_1920_1080_30fps.mp4: 384x640 5 persons, 1 car, 1 bench, 168.1ms
# video 1/1 (frame 3/450) F:\University\Last year of Hell - First Term\Computer Vision\Practical\Practical Task\Detection\854204-hd_1920_1080_30fps.mp4: 384x640 6 persons, 1 car, 1 bench, 91.2ms
# video 1/1 (frame 4/450) F:\University\Last year of Hell - First Term\Computer Vision\Practical\Practical Task\Detection\854204-hd_1920_1080_30fps.mp4: 384x640 7 persons, 1 car, 74.5ms
# video 1/1 (frame 5/450) F:\University\Last year of Hell - First Term\Computer Vision\Practical\Practical Task\Detection\854204-hd_1920_1080_30fps.mp4: 384x640 7 persons, 1 car, 69.2ms
# ...
