# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt

# %%
model = YOLO('yolov8n.pt')

# %%
results = model(source="F:\\University\\Last year of Hell - First Term\\Computer Vision\\Practical\\Practical Task\\Detection\\myimg.jpg", show=True, conf=0.4, save=True)
# Out:
# image 1/1 F:\University\Last year of Hell - First Term\Computer Vision\Practical\Practical Task\Detection\myimg.jpg: 448x640 8 persons, 110.1ms
# Speed: 6.0ms preprocess, 110.1ms inference, 10.6ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to C:\Users\ahmad\runs\detect\predict
