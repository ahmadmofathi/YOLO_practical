# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2

# %%
model = YOLO('yolov8n-seg.pt')  
results = model("F:\\University\\Last year of Hell - First Term\\Computer Vision\\Practical\\Practical Task\\Segmentation\\image.jpg")
# Out:
# image 1/1 F:\University\Last year of Hell - First Term\Computer Vision\Practical\Practical Task\Segmentation\image.jpg: 448x640 15 persons, 8 cars, 1 truck, 1 traffic light, 182.2ms
# Speed: 5.8ms preprocess, 182.2ms inference, 30.8ms postprocess per image at shape (1, 3, 448, 640)

# %%
result_img = results[0].plot()
plt.imshow(result_img)
plt.axis('off')
plt.show()

# %%
cap = cv2.VideoCapture("F:\\University\\Last year of Hell - First Term\\Computer Vision\\Practical\\Practical Task\\Segmentation\\video_before.mp4")

out = cv2.VideoWriter("F:\\University\\Last year of Hell - First Term\\Computer Vision\\Practical\\Practical Task\\Segmentation\\result_video.mp4", cv2.VideoWriter_fourcc(*'mp4v'), cap.get(cv2.CAP_PROP_FPS), 
                    (int(cap.get(3)), int(cap.get(4))))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret: break
        
    result_img = model(frame)[0].plot()  
    out.write(result_img)  
    cv2.imshow("Processed Frame", result_img)  

cap.release()
out.release()
# Out:
# 0: 384x640 7 persons, 3 cars, 1 truck, 1 traffic light, 1 handbag, 1 cell phone, 156.9ms
# Speed: 5.1ms preprocess, 156.9ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 3 cars, 1 traffic light, 1 handbag, 1 cell phone, 126.7ms
# Speed: 2.0ms preprocess, 126.7ms inference, 21.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 cars, 1 traffic light, 1 handbag, 1 cell phone, 112.8ms
# Speed: 3.8ms preprocess, 112.8ms inference, 17.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 3 cars, 1 traffic light, 1 cell phone, 114.7ms
# Speed: 3.0ms preprocess, 114.7ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 1 truck, 1 traffic light, 1 handbag, 1 cell phone, 141.1ms
# Speed: 2.9ms preprocess, 141.1ms inference, 10.8ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
